# %% [markdown]
# # DIU Assistant Experiments
# This notebook demonstrates how to use the RAG pipeline and agent for DIU data.

# %%
from src.ingestion import build_site_index
from src.rag_pipeline import RAGPipeline
from src.agents import DIUAssistantAgent
import os

# %%
# Example: Search for a topic
query = "What are the admission requirements for MCT?"
pipeline = RAGPipeline()
results = pipeline.retrieve(query)
for r in results[:3]:
    print(f"Score: {r.score:.2f} | Title: {r.chunk.title}")
